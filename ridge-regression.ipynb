# %%
# !date
# Out:
# Sat Dec 10 17:06:08 PST 2016

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import normalize
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge

# %% [markdown]
# # Read in training and test data

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# # Response variable

# %%
y_train = df_train[['SalePrice']]
y_train = y_train.fillna(y_train.mean()).values.ravel()
y_train = np.log1p(y_train)

# %% [markdown]
# # Set up covariate matrix

# %%
X_train = df_train.drop(['Id', 'SalePrice'], axis=1)
X_test = df_test.drop(['Id'], axis=1)
X_all = pd.concat([X_train, X_test], axis=0)

X_all_cat = X_all.select_dtypes(include=['object'])
X_all_num = X_all.select_dtypes(exclude=['object'])

#create dummy variables for categorical variables
X_all_cat = pd.get_dummies(X_all_cat)

#impute missing values
X_all_cat = X_all_cat.fillna(X_all_cat.mean())
X_all_num = X_all_num.fillna(X_all_num.mean())

#concatenate variables
X_all = pd.concat([X_all_cat, X_all_num], axis=1)

#split again between train and test
X_train = X_all[:df_train.shape[0]]
X_test = X_all[df_train.shape[0]:]

# %% [markdown]
# # Model fitting

# %%
alphas = [0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 50, 75]

models = [Ridge(random_state=0, alpha=a) for a in alphas]

rmses = [np.sqrt(-cross_val_score(model, X_train, y_train, 
                               cv=5, scoring='neg_mean_squared_error')) 
         for model in models]

plt.plot(alphas, [rmse.mean() for rmse in rmses])

# %% [markdown]
# # Make predictions

# %%
model = Ridge(random_state=0, alpha=10)
model.fit(X_train, y_train)
yhat = model.predict(X_test)

# %%
submission = pd.DataFrame()
submission['Id'] = df_test['Id']
submission['SalePrice'] = np.exp(yhat) - 1

# %%
submission.to_csv('ridge_regression_submission.csv',  index=False)

# %%
submission
# Out:
#         Id      SalePrice
# 0     1461  113765.972202
# 1     1462  149447.707232
# 2     1463  171335.558667
# 3     1464  195440.238859
# 4     1465  197248.967362
# 5     1466  169187.085897
# 6     1467  182660.641667
# 7     1468  162792.968664
# 8     1469  188528.271316
# 9     1470  121230.404888
# 10    1471  170452.784725
# 11    1472  102051.431303
# 12    1473   95650.528347
# 13    1474  143952.952651
# 14    1475  113805.611227
# 15    1476  351084.246897
# 16    1477  246967.460537
# 17    1478  300556.155116
# 18    1479  303211.191359
# 19    1480  486788.612942
# 20    1481  329621.735973
# 21    1482  218033.163995
# 22    1483  169340.257666
# 23    1484  168653.135783
# 24    1485  199407.253294
# 25    1486  190340.151638
# 26    1487  344733.673301
# 27    1488  235708.236159
# 28    1489  185985.394250
# 29    1490  233455.514202
# ...    ...            ...
# 1429  2890   88087.210771
# 1430  2891  130824.676783
# 1431  2892   45693.562099
# 1432  2893   73090.811220
# 1433  2894   55577.640521
# 1434  2895  322875.216106
# 1435  2896  274536.171313
# 1436  2897  208305.733113
# 1437  2898  151423.308114
# 1438  2899  209714.955006
# 1439  2900  158453.464021
# 1440  2901  198561.997110
# 1441  2902  168819.961422
# 1442  2903  316726.342849
# 1443  2904  337476.484241
# 1444  2905   72750.725273
# 1445  2906  202140.632593
# 1446  2907  111339.940655
# 1447  2908  138246.783253
# 1448  2909  154496.738075
# 1449  2910   80863.484952
# 1450  2911   86094.111919
# 1451  2912  152470.865795
# 1452  2913   80374.569232
# 1453  2914   79128.910008
# 1454  2915   85217.546428
# 1455  2916   84845.345813
# 1456  2917  159719.928241
# 1457  2918  111894.842310
# 1458  2919  226054.576518
#
# [1459 rows x 2 columns]
